# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# *Replace the text in this markdown cell with your predictions, and be sure to provide justification for your guess.*

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
y = data['spam']
X = data.copy()
X = data.drop(columns=['spam'])

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 3061            0.00               0.00           0.00           0.0
# 3598            0.00               0.00           0.00           0.0
# 442             0.59               0.09           0.09           0.0
# 2646            0.00               0.00           0.00           0.0
# 4561            0.00               0.00           0.00           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 3061           0.00            0.00               0.0                0.00
# 3598           0.00            0.00               0.0                0.00
# 442            0.29            0.09               0.0                0.59
# 2646           0.00            0.00               0.0                0.00
# 4561           0.00            0.00               0.0                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# ...

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler().fit(X_train, X_test)

# %%
# Fit the Standard Scaler with the training data

# %%
# Scale the training data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-0.34842284, -0.16369984, -0.56097804, ..., -0.02640152,
#         -0.17075151, -0.39811269],
#        [-0.34842284, -0.16369984, -0.56097804, ..., -0.1856163 ,
#         -0.24326415, -0.43890711],
#        [ 1.61311795, -0.09554462, -0.37787351, ...,  0.61699232,
#          5.41272202,  3.54011864],
#        ...,
#        [-0.34842284,  0.22251307, -0.56097804, ...,  0.1480425 ,
#          0.38034458, -0.00585857],
#        [-0.34842284, -0.16369984, -0.35752856, ..., -0.1002218 ,
#         -0.12240975,  0.50250276],
#        [-0.34842284,  1.40387021, -0.56097804, ...,  1.18844877,
#          0.254656  ,  0.2012516 ]])

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression

lrm = LogisticRegression()
lrm.fit(X_train, y_train)
print(f"Training Data Score: {lrm.score(X_train, y_train)}")
print(f"Testing Data Score: {lrm.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9231884057971015
# Testing Data Score: 0.9278887923544744
# /Users/mohamedaltoobli/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
lrm_predictions = lrm.predict(X_test)


# Review the predictions
results_df = pd.DataFrame({"Prediction": lrm_predictions, "Actual": y_test})
results_df
# Out:
#       Prediction  Actual
# 1568           1       1
# 3258           0       0
# 1154           1       1
# 4473           0       0
# 827            1       1
# ...          ...     ...
# 1428           1       1
# 102            0       1
# 4389           0       0
# 2354           0       0
# 1483           1       1
#
# [1151 rows x 2 columns]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
lrm_acc_score = accuracy_score(y_test, lrm_predictions)

print(f"Accuracy Score : {lrm_acc_score}")
# Out:
# Accuracy Score : 0.9278887923544744

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier


rfc = RandomForestClassifier(random_state=1, n_estimators=1000).fit(X_train_scaled, y_train)

#print
print(f'Training Score: {rfc.score(X_train_scaled, y_train)}')
print(f'Testing Score: {rfc.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 0.9991304347826087
# Testing Score: 0.9548218940052129

# %%
# Make and save testing predictions with the saved logistic regression model using the test data

rfc_predictions = rfc.predict(X_test_scaled)

# Review the predictions
results_df_two = pd.DataFrame({"Prediction": rfc_predictions, "Actual": y_test})
results_df_two
# Out:
#       Prediction  Actual
# 1568           1       1
# 3258           0       0
# 1154           1       1
# 4473           0       0
# 827            1       1
# ...          ...     ...
# 1428           1       1
# 102            1       1
# 4389           0       0
# 2354           0       0
# 1483           0       1
#
# [1151 rows x 2 columns]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
acc_score = accuracy_score(y_test, rfc_predictions)
print(f"Accuracy Score : {acc_score}")
# Out:
# Accuracy Score : 0.9548218940052129

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# Using scaled data for the Random Forest Classifier (RFC) can improve its performance, especially in scenarios where features have varying scales. Even though RFC doesn't inherently require scaling, it can still benefit from it, as it helps the algorithm to converge faster and make more accurate predictions. However, if in your specific case, the RFC performed better without scaling, it's worth considering why that might be the case. It could be due to the nature of your dataset or the specific problem you're solving. It's important to experiment and assess which preprocessing techniques work best for your particular task.
